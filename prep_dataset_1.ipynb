# %% [markdown]
# <a href="https://colab.research.google.com/github/Traffix-C23-PC636/scripts/blob/main/prep_dataset_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget http://images.cocodataset.org/zips/train2017.zip
# !wget http://images.cocodataset.org/zips/val2017.zip
# Out:
# --2023-05-22 11:42:29--  http://images.cocodataset.org/zips/val2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.203.33, 3.5.28.223, 54.231.199.225, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.203.33|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 815585330 (778M) [application/zip]
# Saving to: ‘val2017.zip.1’
#
# val2017.zip.1        32%[=====>              ] 250.24M  44.4MB/s    eta 14s    ^C

# %%
# !mkdir datasets
# !unzip train2017.zip -d datasets/COCO
# !rm train2017.zip
# !unzip val2017.zip -d datasets/COCO
# Out:
# mkdir: cannot create directory ‘datasets’: File exists
# Archive:  val2017.zip
# replace datasets/COCO/val2017/000000212226.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# !unzip annotations_trainval2017.zip -d datasets/COCO
# Out:
# --2023-05-22 11:43:00--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.229.17, 3.5.1.139, 52.216.99.187, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.229.17|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘annotations_trainval2017.zip’
#
# annotations_trainva 100%[===================>] 241.19M  43.4MB/s    in 6.2s
#
# 2023-05-22 11:43:06 (38.9 MB/s) - ‘annotations_trainval2017.zip’ saved [252907541/252907541]
#
# Archive:  annotations_trainval2017.zip
#   inflating: datasets/COCO/annotations/instances_train2017.json
#   inflating: datasets/COCO/annotations/instances_val2017.json
#   inflating: datasets/COCO/annotations/captions_train2017.json
#   inflating: datasets/COCO/annotations/captions_val2017.json
#   inflating: datasets/COCO/annotations/person_keypoints_train2017.json
# ...

# %% [markdown]
# FILTER CLASESSES
#
# adjust filter.py with the data you looking for and change the `categories` variable with the selected COCO classes accordingly.

# %%
# !python /content/filter.py
# Out:
# loading annotations into memory...
# Done (t=0.85s)
# creating index...
# index created!
# catIds:  [2, 3, 4, 6, 8]
# 870 images of '' instances
# Saving the images with required categories ...
# 100% 870/870 [06:00<00:00,  2.41it/s]
# Filtering the annotations ...
# new_categories:  [{'supercategory': 'vehicle', 'id': 2, 'name': 'bicycle'}, {'supercategory': 'vehicle', 'id': 3, 'name': 'car'}, {'supercategory': 'vehicle', 'id': 4, 'name': 'motorcycle'}, {'supercategory': 'vehicle', 'id': 6, 'name': 'bus'}, {'supercategory': 'vehicle', 'id': 8, 'name': 'truck'}]
# saving json:

# %%
# !du -h ./datasets/
# Out:
# 788M	./datasets/COCO/val2017
# 2.0M	./datasets/COCO/my_custom_dataset_val/annotations
# 150M	./datasets/COCO/my_custom_dataset_val/images
# 152M	./datasets/COCO/my_custom_dataset_val
# 796M	./datasets/COCO/annotations
# 1.7G	./datasets/COCO
# 1.7G	./datasets/

# %%
# !zip -r data_val.zip ./datasets/COCO/my_custom_dataset_val
# Out:
#   adding: datasets/COCO/my_custom_dataset_val/ (stored 0%)
#   adding: datasets/COCO/my_custom_dataset_val/annotations/ (stored 0%)
#   adding: datasets/COCO/my_custom_dataset_val/annotations/coco_annotation.json (deflated 71%)
#   adding: datasets/COCO/my_custom_dataset_val/images/ (stored 0%)
#   adding: datasets/COCO/my_custom_dataset_val/images/000000008899.jpg (deflated 0%)
#   adding: datasets/COCO/my_custom_dataset_val/images/000000345361.jpg (deflated 0%)
#   adding: datasets/COCO/my_custom_dataset_val/images/000000176037.jpg (deflated 0%)
#   adding: datasets/COCO/my_custom_dataset_val/images/000000266400.jpg (deflated 0%)
#   adding: datasets/COCO/my_custom_dataset_val/images/000000474164.jpg (deflated 0%)
#   adding: datasets/COCO/my_custom_dataset_val/images/000000055167.jpg (deflated 0%)
#   adding: datasets/COCO/my_custom_dataset_val/images/000000542625.jpg (deflated 0%)
#   adding: datasets/COCO/my_custom_dataset_val/images/000000524108.jpg (deflated 0%)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp data_val.zip ./drive/MyDrive
